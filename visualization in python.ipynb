# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import plotly.express as px

# %%
# Create a date range
dates = pd.date_range(start="2020-01-01", periods=100, freq='B')  # 'B' frequency is for business days

# Generate a DataFrame to simulate US stock market data with five related variables
np.random.seed(0)  # For reproducibility
data = {
    'Open': np.random.uniform(100, 200, size=len(dates)),  # Simulated opening price
    'High': np.random.uniform(200, 300, size=len(dates)),  # Simulated daily high price
    'Low': np.random.uniform(50, 100, size=len(dates)),    # Simulated daily low price
    'Close': np.random.uniform(150, 250, size=len(dates)),  # Simulated closing price
    'Volume': np.random.randint(100000, 1000000, size=len(dates))  # Simulated trading volume
}

# Ensure 'High' is greater than 'Open', 'Close', and 'Low'; 'Low' is less than 'Open' and 'Close'
for i in range(len(dates)):
    data['High'][i] = max(data['Open'][i], data['High'][i], data['Close'][i])
    data['Low'][i] = min(data['Open'][i], data['Low'][i], data['Close'][i])

df_stock = pd.DataFrame(data, index=dates)

# Print the first few rows of the DataFrame
df_stock.head()
# Out:
#                   Open        High        Low       Close  Volume
# 2020-01-01  154.881350  267.781654  65.589794  240.655550  686049
# 2020-01-02  171.518937  227.404733  84.817174  227.404733  708704
# 2020-01-03  160.276338  273.519402  68.887592  183.314515  495973
# 2020-01-06  154.488318  296.218855  58.980184  158.110139  505336
# 2020-01-07  142.365480  224.875314  51.233936  190.724117  123842

# %%
df_stock
# Out:
#                   Open        High        Low       Close  Volume
# 2020-01-01  154.881350  267.781654  65.589794  240.655550  686049
# 2020-01-02  171.518937  227.404733  84.817174  227.404733  708704
# 2020-01-03  160.276338  273.519402  68.887592  183.314515  495973
# 2020-01-06  154.488318  296.218855  58.980184  158.110139  505336
# 2020-01-07  142.365480  224.875314  51.233936  190.724117  123842
# ...                ...         ...        ...         ...     ...
# 2020-05-13  118.319136  249.045881  61.215851  245.898272  206833
# 2020-05-14  158.651293  222.741463  54.892224  185.536885  809789
# 2020-05-15  102.010755  225.435648  93.109576  185.670689  193708
# 2020-05-18  182.894003  205.802916  98.645974  151.632850  947478
# 2020-05-19  100.469548  243.441663  98.041733  168.523233  404942
#
# [100 rows x 5 columns]

# %%
df_stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 100 entries, 2020-01-01 to 2020-05-19
# Freq: B
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    100 non-null    float64
#  1   High    100 non-null    float64
#  2   Low     100 non-null    float64
#  3   Close   100 non-null    float64
#  4   Volume  100 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 4.7 KB

# %%
df_stock.describe()
# Out:
#              Open        High         Low       Close         Volume
# count  100.000000  100.000000  100.000000  100.000000     100.000000
# mean   147.279384  254.023399   75.481599  197.275746  551750.580000
# std     28.975402   26.222809   15.160029   28.607535  251033.994394
# min    100.469548  205.433799   50.661843  151.142746  101337.000000
# 25%    120.580316  230.075169   61.927350  174.403048  364872.250000
# 50%    146.748099  257.524129   75.217759  195.652599  571382.500000
# 75%    168.448325  273.002343   89.418820  222.452432  755445.000000
# max    198.837384  299.884701   99.516947  245.943334  991982.000000

# %% [markdown]
# # Visualization: Basics

# %% [markdown]
# # Matplotlib Basics
#
# Key Functions:
#
# plt.plot(): For line plots
#
# plt.scatter(): For scatter plots
#
# plt.bar(): For bar charts
#
# plt.hist(): For histograms
#
# plt.xlabel(), plt.ylabel(): For labeling x and y axes
#
# plt.title(): For setting the title of the plot
#
# plt.legend(): For adding legends
#
# plt.show(): For displaying the plot

# %%
# Sample data
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

plt.plot(x, y)  # Create a line plot
plt.xlabel('X Axis')  # Label for x-axis
plt.ylabel('Y Axis')  # Label for y-axis
plt.title('Line Plot Example')  # Title of the plot
plt.show()  # Display the plot

# %% [markdown]
# # Seaborn Basics
#
# Key Functions:
#
# sns.lineplot(): For line plots
#
# sns.scatterplot(): For scatter plots
#
# sns.barplot(): For bar charts
#
# sns.histplot(): For histograms
#
# sns.boxplot(): For box plots

# %%
# Sample data
categories = ['A', 'B', 'C', 'D']
values = [10, 20, 15, 5]

sns.barplot(x=categories, y=values)  # Create a bar plot
plt.title('Bar Plot Example')  # Title of the plot
plt.show()  # Display the plot

# %%
# Sample data
categories = ['A', 'B', 'C', 'D']
values = [10, 20, 15, 5]

# Create a bar plot using Plotly
fig = px.bar(x=categories, y=values, labels={'x': 'Category', 'y': 'Value'}, title='Bar Plot Example (Plotly)')
fig.show()
# Out:
# <div>                            <div id="0a3aca26-9400-4d13-9c8e-0cb98ea0a557" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0a3aca26-9400-4d13-9c8e-0cb98ea0a557")) {                    Plotly.newPlot(                        "0a3aca26-9400-4d13-9c8e-0cb98ea0a557",                        [{"alignmentgroup":"True","hovertemplate":"Category=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["A","B","C","D"],"xaxis":"x","y":[10,20,15,5],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale
# ...

# %% [markdown]
# # Plotly Basics
#
# Key Functions:
#
# px.line(): For interactive line plots
#
# px.scatter(): For interactive scatter plots
#
# px.bar(): For interactive bar charts
#
# px.histogram(): For interactive histograms

# %%
# Using Plotly's built-in Iris dataset
df = px.data.iris()

# Create an interactive scatter plot
fig = px.scatter(df, x="sepal_width", y="sepal_length", color="species")
fig.show()  # Display the plot interactively
# Out:
# <div>                            <div id="1ebec04c-f065-46ac-9756-3d51c7334894" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1ebec04c-f065-46ac-9756-3d51c7334894")) {                    Plotly.newPlot(                        "1ebec04c-f065-46ac-9756-3d51c7334894",                        [{"hovertemplate":"species=setosa<br>sepal_width=%{x}<br>sepal_length=%{y}<extra></extra>","legendgroup":"setosa","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"setosa","orientation":"v","showlegend":true,"x":[3.5,3.0,3.2,3.1,3.6,3.9,3.4,3.4,2.9,3.1,3.7,3.4,3.0,3.0,4.0,4.4,3.9,3.5,3.8,3.8,3.4,3.7,3.6,3.3,3.4,3.0,3.4,3.5,3.4,3.2,3.1,3.4,4.1,4.2,3.1,3.2,3.5,3.1,3.0,3.4,3.5,2.3,3.2,3.5,3.8,3.0,3.8,3.2,3.7,3.3],"xaxis":"x","y":[5.1,4.9,4.7,4.6
# ...

# %%
iris = sns.load_dataset('iris')  # Load Iris dataset from Seaborn's dataset collection
sns.pairplot(iris, hue='species')  # 'hue' colors points by the 'species' column
plt.show()
# Out:
# /Users/TC/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning:
#
# The figure layout has changed to tight

# %%
df = px.data.iris()

fig = px.scatter_3d(df, x='sepal_length', y='sepal_width', z='petal_width', color='species')
fig.show()
# Out:
# <div>                            <div id="a788a415-4803-4762-9b89-a6cb79e88bb0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a788a415-4803-4762-9b89-a6cb79e88bb0")) {                    Plotly.newPlot(                        "a788a415-4803-4762-9b89-a6cb79e88bb0",                        [{"hovertemplate":"species=setosa<br>sepal_length=%{x}<br>sepal_width=%{y}<br>petal_width=%{z}<extra></extra>","legendgroup":"setosa","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"setosa","scene":"scene","showlegend":true,"x":[5.1,4.9,4.7,4.6,5.0,5.4,4.6,5.0,4.4,4.9,5.4,4.8,4.8,4.3,5.8,5.7,5.4,5.1,5.7,5.1,5.4,5.1,4.6,5.1,4.8,5.0,5.0,5.2,5.2,4.7,4.8,5.4,5.2,5.5,4.9,5.0,5.5,4.9,4.4,5.1,5.0,4.5,4.4,5.0,5.1,4.8,5.1,4.6,5.3,5.0],"y":[3.5,3.0,3
# ...

# %%
# Load the Iris dataset
iris = sns.load_dataset('iris')

# Define the dimensions of the plot grid
n_vars = iris.shape[1] - 1  # Number of variables (excluding the species column)
fig, axes = plt.subplots(n_vars, n_vars, figsize=(12, 12))

# Plot each pair of variables
for i in range(n_vars):
    for j in range(n_vars):
        if i == j:
            # Diagonal: Plot a histogram
            axes[i, j].hist(iris.iloc[:, i], bins=15, color='gray', alpha=0.7)
        else:
            # Off-diagonal: Plot a scatter plot
            axes[i, j].scatter(iris.iloc[:, j], iris.iloc[:, i], alpha=0.7)

        # Set axis labels
        if j == 0:
            axes[i, j].set_ylabel(iris.columns[i])
        if i == n_vars - 1:
            axes[i, j].set_xlabel(iris.columns[j])

        # Remove axis labels for non-edge plots
        if i != n_vars - 1:
            axes[i, j].set_xlabel('')
        if j != 0:
            axes[i, j].set_ylabel('')

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# # Matplotlib Intermediate Functions
#
# Customizing Plot Styles:
#
# Use plt.style.use() to change the style of your plots. Matplotlib has several built-in styles like 'ggplot', 'seaborn', 'classic', etc.
# Annotation:
#
# Use plt.annotate() to add text annotations to specific points in your plot, which is useful for highlighting key observations.
#
# Multiple Axes and Twin Axes:
#
# Use fig.add_subplot() or plt.subplots() for creating figures with multiple axes.
# Use ax.twinx() or ax.twiny() to create a secondary y-axis or x-axis, respectively.
#
# Error Bars:
#
# Use plt.errorbar() to create plots with error bars, which are essential for visualizing the variability in your data.
#
#
# # Seaborn Intermediate Functions
#
# Facet Grid:
# sns.FacetGrid allows you to create a grid of subplots based on the values of one or more categorical variables.
# Joint Plot:
#
# sns.jointplot() creates a multi-panel figure that shows both the bivariate (scatter plot, hexbin plot) and univariate (histogram, KDE) distribution of two variables.
#
# KDE Plot:
# sns.kdeplot() for Kernel Density Estimation plots, which are useful for visualizing the distribution of data.
#
# Violin Plot:
# sns.violinplot() combines box plot and kernel density plot, providing a deeper understanding of the distribution of the data.
#
# # Plotly Intermediate Functions
#
# Subplots:
# Use plotly.subplots.make_subplots() to create figures with multiple subplots.
#
# 3D Plots:
# Functions like px.scatter_3d() and px.line_3d() for creating three-dimensional plots.
#
# Time Series:
# px.line() is great for time series data, with options for easy zooming, panning, and dynamic time-formatting on axes.
#
# Categorical Data Plots:
# Functions like px.box() and px.violin() for plotting categorical data.

# %% [markdown]
# # Matplotlib: Customizing Plot Styles and Annotation

# %%
plt.style.use('ggplot')  # Apply the 'ggplot' style to the plots for a certain aesthetic (similar to R's ggplot2)
x = np.linspace(0, 10, 100)  # Generate 100 points between 0 and 10
y = np.sin(x)  # Compute the sine of each x value

plt.plot(x, y)  # Plot y vs. x as lines
plt.annotate('Local Max', xy=(np.pi/2, 1), xytext=(np.pi/2+1, 0.5),
             arrowprops=dict(facecolor='black', shrink=0.05))  # Annotate a point with text and an arrow
plt.show()  # Display the plot

# %% [markdown]
# # Seaborn: Facet Grid

# %%
tips = sns.load_dataset("tips")  # Load the 'tips' dataset from Seaborn's dataset collection
g = sns.FacetGrid(tips, col="time", row="smoker")  # Create a FacetGrid. Each subplot will correspond to a combination of 'time' and 'smoker'
g.map(plt.hist, "total_bill")  # Map a histogram to each subplot based on the 'total_bill' column
plt.show()  # Display the plot
# Out:
# /Users/TC/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning:
#
# The figure layout has changed to tight

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")
g = sns.FacetGrid(tips, col="time", row="smoker")
g.map(plt.hist, "total_bill")

# Iterate over each subplot (ax) in the FacetGrid and set the same y-axis limits
max_count = tips['total_bill'].value_counts().max()
g.set(ylim=(0, max_count))

plt.show()
# Out:
# /Users/TC/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning:
#
# The figure layout has changed to tight

# %% [markdown]
# # Plotly Maps

# %%
import plotly.express as px

# Using a built-in dataset for demonstration
df = px.data.gapminder().query("year==2007")

# Create a choropleth map
fig = px.choropleth(df, locations="iso_alpha",
                    color="gdpPercap", 
                    hover_name="country",
                    color_continuous_scale=px.colors.sequential.Plasma)
fig.show()
# Out:
# <div>                            <div id="21f7c67c-2f54-4ed6-82f7-cc6f38ac8e80" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("21f7c67c-2f54-4ed6-82f7-cc6f38ac8e80")) {                    Plotly.newPlot(                        "21f7c67c-2f54-4ed6-82f7-cc6f38ac8e80",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>iso_alpha=%{location}<br>gdpPercap=%{z}<extra></extra>","hovertext":["Afghanistan","Albania","Algeria","Angola","Argentina","Australia","Austria","Bahrain","Bangladesh","Belgium","Benin","Bolivia","Bosnia and Herzegovina","Botswana","Brazil","Bulgaria","Burkina Faso","Burundi","Cambodia","Cameroon","Canada","Central African Republic","Chad","Chile","China","Colombia","Comoros","Congo
# ...

# %% [markdown]
# # Plotly Subplots
#
# Subplots allow you to display multiple plots in a single figure, which is useful for comparing different but related datasets.

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Creating a subplot layout with 1 row and 2 columns
fig = make_subplots(rows=1, cols=2)  # Initialize a figure with subplots

# Adding a scatter plot to the first subplot
fig.add_trace(
    go.Scatter(x=[1, 2, 3], y=[4, 5, 6]),  # Scatter plot data
    row=1, col=1  # Position in the subplot grid
)

# Adding a bar plot to the second subplot
fig.add_trace(
    go.Bar(x=[1, 2, 3], y=[6, 5, 4]),  # Bar plot data
    row=1, col=2  # Position in the subplot grid
)

fig.show()  # Display the figure
# Out:
# <div>                            <div id="34568100-cbcf-4095-8baf-e6575228c1f9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("34568100-cbcf-4095-8baf-e6575228c1f9")) {                    Plotly.newPlot(                        "34568100-cbcf-4095-8baf-e6575228c1f9",                        [{"x":[1,2,3],"y":[4,5,6],"type":"scatter","xaxis":"x","yaxis":"y"},{"x":[1,2,3],"y":[6,5,4],"type":"bar","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.666666666
# ...

# %%
import plotly.express as px

df = px.data.gapminder()  # Load a sample dataset

# Create an animated scatter plot
fig = px.scatter(df, x="gdpPercap", y="lifeExp", 
                 animation_frame="year", 
                 animation_group="country",
                 size="pop", color="continent", 
                 hover_name="country", 
                 log_x=True, size_max=55)

fig.show()  # Display the figure
# Out:
# <div>                            <div id="4caf603a-49ce-413d-8535-dc5816527dfe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4caf603a-49ce-413d-8535-dc5816527dfe")) {                    Plotly.newPlot(                        "4caf603a-49ce-413d-8535-dc5816527dfe",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>continent=Asia<br>year=1952<br>gdpPercap=%{x}<br>lifeExp=%{y}<br>pop=%{marker.size}<extra></extra>","hovertext":["Afghanistan","Bahrain","Bangladesh","Cambodia","China","Hong Kong, China","India","Indonesia","Iran","Iraq","Israel","Japan","Jordan","Korea, Dem. Rep.","Korea, Rep.","Kuwait","Lebanon","Malaysia","Mongolia","Myanmar","Nepal","Oman","Pakistan","Philippines","Saudi Arabia","Singapore","Sri Lanka","Syria","Ta
# ...

# %% [markdown]
# # Seaborn Advanced Features
#
# PairGrid (Customizable Pairplot):
#
# Seaborn's PairGrid allows for more control compared to pairplot. It lets you specify which plots to use on the diagonal, upper half, and lower half of the grid.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

iris = sns.load_dataset('iris')

# Initialize the PairGrid
g = sns.PairGrid(iris, hue="species")
g.map_upper(sns.scatterplot)  # Upper triangle with scatter plots
g.map_lower(sns.kdeplot)  # Lower triangle with KDE plots
g.map_diag(sns.histplot)  # Diagonal with histograms
g.add_legend()  # Add a legend

plt.show()

# %% [markdown]
# # Clustermap (Advanced Heatmap):
#
# Seaborn's clustermap is used for hierarchically-clustered heatmaps, which are great for visualizing complex matrices.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(color_codes=True)  # Set the theme for Seaborn plots

# Load and pivot the sample data
flights = sns.load_dataset("flights")
flights_pivoted = flights.pivot(index="month", columns="year", values="passengers")  # Corrected pivot call

# Draw a clustermap
sns.clustermap(flights_pivoted, cmap="mako", standard_scale=1)  # Create a clustermap
plt.show()  # Display the plot

# %% [markdown]
# # Matplotlib Advanced Features
#
# 3D Plotting:
# Matplotlib can create 3D plots, which are useful for visualizing three-dimensional data.

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Data for a three-dimensional scatter
x = np.random.standard_normal(100)
y = np.random.standard_normal(100)
z = np.random.standard_normal(100)
ax.scatter(x, y, z)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()

# %% [markdown]
# # Customizing Plots with Matplotlib:
#
# Matplotlib's real power lies in its ability to be highly customizable. This includes modifying plot elements, adding annotations, and working with axes.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y, linestyle='--', color='green', marker='o', markersize=5)
plt.title('Customized Sin Wave')
plt.xlabel('X')
plt.ylabel('Sin(X)')
plt.grid(True)
plt.fill_between(x, y, color='green', alpha=0.1)

plt.show()

# %%
import plotly.express as px
import seaborn as sns
import pandas as pd

# Load and pivot the sample data
flights = sns.load_dataset("flights")
flights_pivoted = flights.pivot(index="month", columns="year", values="passengers")

# Create a heatmap with Plotly
fig = px.imshow(flights_pivoted, 
                labels=dict(x="Year", y="Month", color="Passengers"),
                x=flights_pivoted.columns,
                y=flights_pivoted.index,
                title="Flight Passengers Heatmap")
fig.show()
# Out:
# <div>                            <div id="217a6e5c-1570-492b-8592-b8326fea87f4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("217a6e5c-1570-492b-8592-b8326fea87f4")) {                    Plotly.newPlot(                        "217a6e5c-1570-492b-8592-b8326fea87f4",                        [{"coloraxis":"coloraxis","name":"0","x":[1949,1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,1960],"y":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"z":[[112,115,145,171,196,204,242,284,315,340,360,417],[118,126,150,180,196,188,233,277,301,318,342,391],[132,141,178,193,236,235,267,317,356,362,406,419],[129,135,163,181,235,227,269,313,348,348,396,461],[121,125,172,183,229,234,270,318,355,363,420,472],[135,149,178,218,243,264,315,374
# ...

# %%
# Matplotlib: Plotting 'Close' prices over time
plt.figure(figsize=(12, 6))
plt.plot(df_stock.index, df_stock['Close'], label='Close Price', color='blue')
plt.title('Stock Market Closing Prices Over Time (Matplotlib)')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.show()

# Seaborn: Using Seaborn's styling on the same plot
sns.set(style="darkgrid")
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_stock, x=df_stock.index, y='Close', label='Close Price', color='red')
plt.title('Stock Market Closing Prices Over Time (Seaborn)')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.show()


# Creating an interactive line plot with Plotly
fig = px.line(df_stock, y='Close', title='Interactive Stock Market Closing Prices (Plotly)')
fig.update_xaxes(title_text='Date')
fig.update_yaxes(title_text='Close Price')
# fig.show() would display the plot in an interactive environment
# Out:
# <div>                            <div id="a1cf867d-cb84-4695-b553-5b7602806696" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a1cf867d-cb84-4695-b553-5b7602806696")) {                    Plotly.newPlot(                        "a1cf867d-cb84-4695-b553-5b7602806696",                        [{"hovertemplate":"index=%{x}<br>Close=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2020-01-01T00:00:00","2020-01-02T00:00:00","2020-01-03T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-09T00:00:00","2020-01-10T00:00:00","2020-01-13T00:00:00","2020-01-14T00:00:00","2020-01-15T00:00:00","2020-01-16
# ...

# %% [markdown]
# # 2. Ease of Creating Complex Visualizations

# %%
plt.figure(figsize=(12, 6))
plt.scatter(df_stock.index, df_stock['Close'], s=df_stock['Volume']/10000)  # Size scaled down for visibility
plt.title('Complex Scatter Plot with Volume Indicators (Matplotlib/Seaborn)')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.show()

# %% [markdown]
# # Plotly Code

# %%
fig = px.scatter(df_stock, x=df_stock.index, y='Close', size='Volume', color='Volume',
                 title='Complex Scatter Plot with Volume Indicators (Plotly)')
fig.show()
# Out:
# <div>                            <div id="9d6b9d8d-0ee8-464b-8184-e845ee78ca1b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9d6b9d8d-0ee8-464b-8184-e845ee78ca1b")) {                    Plotly.newPlot(                        "9d6b9d8d-0ee8-464b-8184-e845ee78ca1b",                        [{"hovertemplate":"index=%{x}<br>Close=%{y}<br>Volume=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[686049,708704,495973,505336,123842,300655,483676,545678,361291,347507,274936,558310,435508,584230,988604,776467,596518,760290,681596,464134,846341,971803,775525,416086,174573,499253,941211,125247,414961,348867,124813,934803,409498,196648,680350,338873,575157,122957,609157,138870,583728,486030,693015,404805,665119,752673,883749,609638,139308,234
# ...

# %%
# Creating a bar chart using both Matplotlib and Seaborn for comparison

# Using Matplotlib directly
plt.figure(figsize=(12, 6))
plt.bar(df_stock.index, df_stock['Close'], color='skyblue')
plt.xticks(rotation=45)
plt.title('Bar Chart of Closing Prices (Matplotlib)')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.show()

# Using Seaborn for bar chart
plt.figure(figsize=(12, 6))
sns.barplot(x=df_stock.index, y='Close', data=df_stock, color='salmon')
plt.xticks(rotation=45)
plt.title('Bar Chart of Closing Prices (Seaborn)')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.show()

# %%
import plotly.express as px

fig = px.bar(df_stock, y='Close', title='Interactive Bar Chart of Closing Prices (Plotly)')
fig.update_xaxes(title_text='Date')
fig.update_yaxes(title_text='Close Price')
# fig.show()  # Run this in an interactive environment
# Out:
# <div>                            <div id="998a20cc-b620-433c-807d-6acab11bfbe0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("998a20cc-b620-433c-807d-6acab11bfbe0")) {                    Plotly.newPlot(                        "998a20cc-b620-433c-807d-6acab11bfbe0",                        [{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>Close=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["2020-01-01T00:00:00","2020-01-02T00:00:00","2020-01-03T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-09T00:00:00","2020-01-10T00:00:00","2020-01-13T00:00:00","2020-01-14T00:00:00","202
# ...
